# %% [markdown]
# # Project Title

# %% [markdown]
# # Simple Study Planner
#
# This project is a simple Python study planner. It helps a student calculate an average grade, check how many days are left before a deadline, calculate a task priority score, and create a short study plan sentence.
#
# I chose this project because it is simple, useful, and related to our life. The inspiration for this project came from a controlled variable experimental question in my Econ 110A final exam. This question discuss about what factors affect students' test scores. I chose this topic because it also shows my understanding of basic Python knowledges.

# %% [markdown]
# ## Project Code
#
# Demonstrate how your project works here! (If it doesn't work from the notebook, describe what graders should do to execute your project.)

# %%
import module

# %%
scores = [85, 90, 95]
average_grade = module.calculate_grade(scores)
print("Average grade:", average_grade)

due_date = "2026-06-15"
days = module.days_left(due_date)
print("Days left before due date:", days)

importance = 5
days = 3
priority = module.task_priority(importance, days)
print("Task priority score:", priority)

plan = module.make_study_plan("final project", 4)
print(plan)
# Out:
# Average grade: 90.0
# Days left before due date: 7
# Task priority score: 47
# Study final project for about 4 hour(s).

# %% [markdown]
# #### Testing
#
# Run your tests. Sample code is provided below; you may need to edit this, depending upon how you've set up your tests.

# %%
# test it out
import unittest
import tests

unittest.main(tests, argv=[""], verbosity=2, exit=False)
# Out:
# test_calculate_grade (tests.TestStudyPlanner.test_calculate_grade) ... ok
# test_make_study_plan (tests.TestStudyPlanner.test_make_study_plan) ... ok
# test_task_priority (tests.TestStudyPlanner.test_task_priority) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.011s
#
# OK

# %% [markdown]
# #### GenAI Statement
#
# I used GenAI to help me choose a simple project topic, organize the project files, and improve the wording of comments and docstrings. I reviewed the code myself and made sure I understood what each function does. The final project shows my own understanding of Python functions, lists, dates, strings, and unit testing.

# %% [markdown]
# #### Extra Credit (*optional*)
#
# My Python background includes basic topics such as variables, lists, functions, strings, and simple testing. For this project, I challenged myself by organizing the code into separate files, including `module.py`, `tests.py`, `script.py`, and a notebook. I also used numpy-style docstrings and unit tests to make the project clearer and easier to check.
